# %%
import pickle
filename='Finalized_random_forest_model.sav'
loaded_model = pickle.load(open(filename,'rb'))

# %%
result = loaded_model.predict([[98798, 989, 987, 0, 0]])
result
# Out:
# C:\Users\PRAPANJANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([134340.3578])
