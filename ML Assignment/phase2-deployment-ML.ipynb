# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_model_liner.sav", 'rb'))
result = loaded_model.predict([[13]])
result
# Out:
# C:\Users\PRAPANJANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[148460.78806172]])
