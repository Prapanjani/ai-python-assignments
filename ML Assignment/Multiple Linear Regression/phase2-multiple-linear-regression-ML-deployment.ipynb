# %%
import pickle #library
filename = "finalized_model_multiple_linear_regression.sav" #create a filename
loaded_model = pickle.load(open(filename, "rb")) #loading file 
result = loaded_model.predict([[66051.52, 182645.56, 118148.20,	1, 0]]) #predict new value
result
# Out:
# C:\Users\PRAPANJANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[104282.76472172]])
