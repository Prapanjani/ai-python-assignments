# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes
# 0           True
# 1          False
# 2          False
# ...

# %%
independent = dataset[['age','bmi','children','sex_female','sex_male','smoker_no','smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0        True     False      False        True
# 1      18  33.770         1       False      True       True       False
# 2      28  33.000         3       False      True       True       False
# 3      33  22.705         0       False      True       True       False
# 4      32  28.880         0       False      True       True       False
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3       False      True       True       False
# 1334   18  31.920         0        True     False       True       False
# 1335   18  36.850         0        True     False       True       False
# 1336   21  25.800         0        True     False       True       False
# 1337   61  29.070         0        True     False      False        True
#
# [1338 rows x 7 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.3, random_state=0)

# %%
x_train,x_test,y_train,y_test
# Out:
# (      age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
#  1163   18  28.215         0        True     False       True       False
#  196    39  32.800         0        True     False       True       False
#  438    52  46.750         5        True     False       True       False
#  183    44  26.410         0        True     False       True       False
#  1298   33  27.455         2       False      True       True       False
#  ...   ...     ...       ...         ...       ...        ...         ...
#  763    27  26.030         0       False      True       True       False
#  835    42  35.970         2       False      True       True       False
#  1216   40  25.080         0       False      True       True       False
#  559    19  35.530         0       False      True       True       False
#  684    33  18.500         1        True     False       True       False
#
#  [936 rows x 7 columns],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.svm import SVR

# %%
# Define parameter grid
# param_grid = {
#     'kernel': ['linear', 'rbf', 'poly'],
#     'C': [0.1, 1, 10, 100],
#     'epsilon': [0.01, 0.1, 0.5, 1],
#     'gamma': ['scale', 'auto']  # or numeric values like 0.01, 0.1, 1
# }

# %%
regressor = SVR(kernel='poly',C=100, epsilon=1, gamma=1)
regressor.fit(x_train,y_train)
# Out:
# C:\Users\PRAPANJANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, epsilon=1, gamma=1, kernel='poly')

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([10022.22832328,  8734.61438758, 48704.94025856, 12592.81300835,
#        10644.38386171,  4517.59804735,  1545.10957747, 11113.62137771,
#         7302.22846394,  5269.73267477,  7005.54301419, 10271.81782381,
#         7571.31915067,  4845.99514415, 25336.03485093, 10829.22359152,
#        12361.51485493,  3218.66478285,  6470.54856577, 23776.46358429,
#        26202.68187072, 12223.77228498,  9803.91111213, 31457.20669936,
#         1811.91538862,  4541.83370398,  4525.86128441,  7831.30411821,
#         4301.24596779,  8412.374404  ,  7854.17959323, 51984.47626522,
#        13030.11947609, 10230.51772462, 12178.02276265,  4004.45278876,
#         8755.11236426, 36545.89971394, 37562.65486561,  2049.67362742,
#         6048.13883104,  3115.92642005, 27803.26151131, 44969.7983874 ,
#        33776.96823849,  2923.64735495, 10839.92212621,  6985.00735836,
#         4633.87278273, 12314.29117019,  2656.99433048,  2868.92662815,
# ...

# %%
from sklearn.metrics import r2_score
rScore = r2_score(y_test,y_pred)

# %%
rScore
# Out:
# 0.8576975692314952

# %% [markdown]
# #####

# %%
import pickle
filename = "finalized_model_svm.sav"
pickle.dump(regressor, open(filename, 'wb'))
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict([[28, 29.215, 0, True, False, True, False]])
result
# Out:
# array([2208154.2386427])
