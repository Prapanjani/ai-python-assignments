# %%
import pickle
loaded_model = pickle.load(open("finalized_model_svm.sav", 'rb'))
result = loaded_model.predict([[48, 39.215, 0, False, True, True, False]])
result
# Out:
# array([11724548.04903492])
